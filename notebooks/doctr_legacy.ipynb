# %% [markdown]
# Looking for some examples on how to use docTR for OCR-related tasks? You've come to the right place 😀

# %% [markdown]
# # Installation
#
# Install all the dependencies to make the most out of docTR. The project provides two main [installation](https://mindee.github.io/doctr/latest/installing.html) streams: one for stable release, and developer mode.

# %% [markdown]
# # Basic usage
#
# We're going to review the main features of docTR 🎁
# And for you to have a proper overview of its capabilities, we will need some free fonts for a proper output visualization:

# %% [markdown]
# Let's take care of all the imports directly

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from doctr.io import DocumentFile
from doctr.models import ocr_predictor
import torch
print(torch.cuda.is_available())  # Doit renvoyer True
# Out:
# True

# %% [markdown]
# ## Basic inference
#
# It looks quite complex, isn't it?
# Well that will not prevent you from easily get nice results. See for yourself:

# %%
document_name = "page1-656px-History_of_Factories,_1920,_Handwritten_notes.jpg"
doc = DocumentFile.from_images("dataset/" + document_name)

# %%
# Download a sample
document_name = "History_of_Business-_1892-_handwritten_notes_(1).pdf"
document_name = "Cash-Payment-Receipt-Template.pdf"
#document_name = "Lettre_Feudataire_abbaye_de_Mercoire.pdf"
#document_name = "COI-handwritten notes.pdf"
doc = DocumentFile.from_pdf("dataset/"+document_name)

# %%
predictor = ocr_predictor(det_arch='db_resnet50', reco_arch='vitstr_small', pretrained=True)
predictor = ocr_predictor(det_arch='db_resnet50', reco_arch='parseq', pretrained=True)
# Déplacer sur GPU si disponible
predictor.cuda().half() 
result = predictor(doc)
result.show()

# %% [markdown]
# Looks accurate!
# But we can go further: if the extracted information is correctly structured, we should be able to recreate the page entirely. So let's do this 🎨

# %%
synthetic_pages = result.synthesize()
plt.imshow(synthetic_pages[0]); plt.axis('off'); plt.show()

# %% [markdown]
# ## Exporting results
#
# OK, so the predictions are relevant, but how would you integrate this into your own document processing pipeline? Perhaps you're not using Python at all?
#
# Well, if you happen to be using JSON or XML exports, they are already supported 🤗

# %%
# JSON export
json_export = result.export()
print(json_export)
# Out:
# {'pages': [{'page_idx': 0, 'dimensions': (1584, 1224), 'orientation': {'value': None, 'confidence': None}, 'language': {'value': None, 'confidence': None}, 'blocks': [{'geometry': ((np.float64(0.11580882352941174), np.float64(0.0625)), (np.float64(0.9132582720588236), np.float64(0.95703125))), 'objectness_score': 0.5592447916666666, 'lines': [{'geometry': ((np.float64(0.3142233455882353), np.float64(0.0625)), (np.float64(0.6857766544117647), np.float64(0.083984375))), 'objectness_score': 0.5935872395833334, 'words': [{'value': 'CASH', 'confidence': 1.0, 'geometry': ((np.float64(0.3142233455882353), np.float64(0.0625)), (np.float64(0.39763327205882354), np.float64(0.083984375))), 'objectness_score': 0.55810546875, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'PAYMENT', 'confidence': 1.0, 'geometry': ((np.float64(0.40774356617647056), np.float64(0.064453125)), (np.float64(0.5492876838235294), np.float64(0.08203125))), 'objectness_score': 0.60205078125, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'RECEIPT', 'confidence': 1.0, 'geometry': ((np.float64(0.5606617647058824), np.float64(0.064453125)), (np.float64(0.6857766544117647), np.float64(0.08203125))), 'objectness_score': 0.62060546875, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.11707261029411764), np.float64(0.1142578125)), (np.float64(0.2775735294117647), np.float64(0.1328125))), 'objectness_score': 0.56201171875, 'words': [{'value': 'Company', 'confidence': 1.0, 'geometry': ((np.float64(0.11707261029411764), np.float64(0.1142578125)), (np.float64(0.21185661764705882), np.float64(0.1328125))), 'objectness_score': 0.55908203125, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'Name:', 'confidence': 1.0, 'geometry': ((np.float64(0.21438419117647056), np.float64(0.1142578125)), (np.float64(0.2775735294117647), np.float64(0.1298828125))), 'objectness_score': 0.56494140625, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.11833639705882354), np.float64(0.1318359375)), (np.float64(0.2661994485294118), np.float64(0.1494140625))), 'objectness_score': 0.5419921875, 'words': [{'value': 'Street', 'confidence': 1.0, 'geometry': ((np.float64(0.11833639705882354), np.float64(0.1328125)), (np.float64(0.1764705882352941), np.float64(0.1484375))), 'objectness_score': 0.5556640625, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'Address:', 'confidence': 1.0, 'geometry': ((np.float64(0.177734375), np.float64(0.1318359375)), (np.float64(0.2661994485294118), np.float64(0.1494140625))), 'objectness_score': 0.5283203125, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.11580882352941174), np.float64(0.150390625)), (np.float64(0.26493566176470584), np.float64(0.1708984375))), 'objectness_score': 0.5859375, 'words': [{'value': 'City,', 'confidence': 1.0, 'geometry': ((np.float64(0.11580882352941174), np.float64(0.150390625)), (np.float64(0.16130514705882354), np.float64(0.1708984375))), 'objectness_score': 0.59326171875, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'State,', 'confidence': 1.0, 'geometry': ((np.float64(0.16383272058823528), np.float64(0.1513671875)), (np.float64(0.22323069852941174), np.float64(0.169921875))), 'objectness_score': 0.57421875, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'Zip:', 'confidence': 1.0, 'geometry': ((np.float64(0.22449448529411764), np.float64(0.1513671875)), (np.float64(0.26493566176470584), np.float64(0.1708984375))), 'objectness_score': 0.59033203125, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.11707261029411764), np.float64(0.1689453125)), (np.float64(0.18658088235294118), np.float64(0.1865234375))), 'objectness_score': 0.56884765625, 'words': [{'value': 'Phone:', 'confidence': 1.0, 'geometry': ((np.float64(0.11707261029411764), np.float64(0.1689453125)), (np.float64(0.18658088235294118),  ...

# %%
# XML export
xml_output = result.export_as_xml()
print(xml_output[0][0])
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en"><head><title>docTR - XML export (hOCR)</title><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="ocr-system" content="python-doctr v0.11.0" /><meta name="ocr-capabilities" content="ocr_page ocr_carea ocr_par ocr_line ocrx_word" /></head><body><div class="ocr_page" id="page_1" title="image; bbox 0 0 1224 1584; ppageno 0" /><div class="ocr_carea" id="block_1" title="bbox 142 99                     1118 1516"><p class="ocr_par" id="par_1" title="bbox 142 99                     1118 1516"><span class="ocr_line" id="line_1" title="bbox 385 99                         839 133;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_1" title="bbox 385 99                             487 133;                             x_wconf 100">CASH</span><span class="ocrx_word" id="word_2" title="bbox 499 102                             672 130;                             x_wconf 100">PAYMENT</span><span class="ocrx_word" id="word_3" title="bbox 686 102                             839 130;                             x_wconf 100">RECEIPT</span></span><span class="ocr_line" id="line_2" title="bbox 143 181                         340 210;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_4" title="bbox 143 181                             259 210;                             x_wconf 100">Company</span><span class="ocrx_word" id="word_5" title="bbox 262 181                             340 206;                             x_wconf 100">Name:</span></span><span class="ocr_line" id="line_3" title="bbox 145 209                         326 237;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_6" title="bbox 145 210                             216 235;                             x_wconf 100">Street</span><span class="ocrx_word" id="word_7" title="bbox 218 209                             326 237;                             x_wconf 100">Address:</span></span><span class="ocr_line" id="line_4" title="bbox 142 238                         324 271;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_8" title="bbox 142 238                             197 271;                             x_wconf 100">City,</span><span class="ocrx_word" id="word_9" title="bbox 201 240                             273 269;                             x_wconf 100">State,</span><span class="ocrx_word" id="word_10" title="bbox 275 240                             324 271;                             x_wconf 100">Zip:</span></span><span class="ocr_line" id="line_5" title="bbox 143 268                         228 295;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_11" title="bbox 143 268                             228 295;                             x_wconf 100">Phone:</span></span><span class="ocr_line" id="line_6" title="bbox 145 300                         197 325;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_12" title="bbox 145 300                             197 325;                             x_wconf 100">Fax:</span></span><span class="ocr_line" id="line_7" title="bbox 145 329                         218 354;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_13" title="bbox 145 329                             218 354;                             x_wconf 100">Email:</span></span><span class="ocr_line" id="line_8" title="bbox 143 360                         245 384;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_14" title="bbox 143 360                             245 384;                             x_wc ...

# %% [markdown]
# Or if you only need the extracted plain text

# %%
string_result = result.render()
print(string_result)
# Out:
# CASH PAYMENT RECEIPT
# Company Name:
# Street Address:
# City, State, Zip:
# Phone:
# Fax:
# Email:
# Website:
# Date:
# Receipt #:
# Payment Information
# Paid By:
# Amount Paid:
# Dollars ($
# For Payment Of:
# Subtotal: $
# Tax Rate (%):
# Total Tax: $
# Total Amount Due: $
# Amount Paid: $
# Remaining Balance: $
# Received By:
# Authorized Signature
# Page 1 of 1
